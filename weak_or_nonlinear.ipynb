# %%
import numpy as np
import pandas as pd

# %%
n_tests=100
N = 10_000

alphas = np.random.uniform(1.0, 10.0, size=(n_tests, 7))
betas = np.random.uniform(0.005, 0.02, size=(n_tests, 2)) #0.01*np.ones((n_tests,2)) #
